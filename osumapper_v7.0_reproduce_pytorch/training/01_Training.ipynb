# %% [markdown]
# ## osumapper #1: Map Dataset Reader
#
# Read the map list and convert maps to formats Python can use.

# %% [markdown]
# ### IMPORTANT!! First fill "maplist.txt" with paths of .osu files you want to train with !!!
#
# You can use the maplist generator by running `node gen_maplist` under this directory.
#
# **Tip:** Don't train with your every single map. Find good maps (maps you like) with relatively similar difficulty.
#
# After that, run the grid below to convert the maps.

# %%
# from act_data_prep import *

# for osu!mania use this instead of above
# from mania_act_data_prep import * 

# step1_load_maps()

# If any map causes bug please tell me!! https://discord.gg/npmSy7K
# Out:
# Number of filtered maps: 10
# Map data #0 saved! time = 1.0609986782073975 secs
# Map data #1 saved! time = 0.608999490737915 secs
# Map data #2 saved! time = 0.6539993286132812 secs
# Map data #3 saved! time = 0.39400291442871094 secs
# Map data #4 saved! time = 0.8529984951019287 secs
# Map data #5 saved! time = 0.8659992218017578 secs
# Map data #6 saved! time = 0.6810002326965332 secs
# Map data #7 saved! time = 0.9519996643066406 secs
# Map data #8 saved! time = 0.714000940322876 secs
# Map data #9 saved! time = 0.6370007991790771 secs

# %% [markdown]
# ## osumapper #2: rhythm model
#
# Train a rhythm model that decides where to place circles/sliders based on music.
#
# If you're using GPU and it reports a memory error, try setting batch_size parameter to a smaller value (that GPU can handle).

# %%
from act_train_rhythm_torch import *

train_params_p2 = {
    "divisor" : 4,
    "train_epochs" : 16,
    "train_batch_size" : None, # Default is 32 or based on machine specs
    "plot_history" : True,
    "too_many_maps_threshold" : 200,
    "train_epochs_many_maps" : 6,
    "data_split_count" : 80
}
model_p2 = step2_build_model()
# Out:
# (1774, 7, 32, 2)
# (1774, 7)
# (1774, 5)
# 7

# %% [markdown]
# Train the model and evaluate.<br>
# is_note_start accuracy should be about 0.8 to 0.9 based on my tests, others should be lower.
#
# **Note:** I changed the metrics from F1 to AUC in this version!! 0.5=guessing 1=perfect for AUC

# %%
model_p2 = step2_train_model(model_p2, train_params_p2)
step2_evaluate(model_p2)
# Out:
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 1.1077892780303955
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.5959956645965576
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 1.5873594284057617
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.606142520904541
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.4607059955596924
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.3906383514404297
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.35920870304107666
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.34940922260284424
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.34635627269744873
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.3437613844871521
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.3413451313972473
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.3390420377254486
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.33652350306510925
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.3340768814086914
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.3315434157848358
# torch.Size([12341, 7, 32, 2])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 16, 31, 1])
# torch.Size([12341, 496])
# torch.Size([12341, 496])
# torch.Size([12341, 16, 496])
# torch.Size([12341, 16, 64])
# torch.Size([12341, 7])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 71])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# torch.Size([12341, 5])
# loss: 0.32903337478637695
# torch.Size([233, 7, 32, 2])
# torch.Size([233, 16, 31, 1])
# torch.Size([233, 16, 31, 1])
# torch.Size([233, 16, 31, 1])
# torch.Size([233, 16, 31, 1])
# torch.Size([233, 16, 31, 1])
# torch.Size([233, 16, 31, 1])
# torch.Size([233, 496])
# torch.Size([233, 496])
# torch.Size([233, 16, 496])
# torch.Size([233, 16, 64])
# torch.Size([233, 7])
# torch.Size([233, 71])
# torch.Size([233, 71])
# torch.Size([233, 71])
# torch.Size([233, 5])
# is_note_start auc score: 0.8976017943409247
# is_circle auc score: 0.459500215424386
# is_slider auc score: 0.7361538461538462
# is_note_end auc score: 0.8443148021047815

# %% [markdown]
# Done! now save the model to the disk.

# %%
step2_save(model_p2)

# %% [markdown]
# ## osumapper #3: flow dataset construction
#
# Construct a dataset for the map flow generator.

# %%
from act_flow_ds import *

flow_dataset_params = step3_set_params(note_group_size=10, step_size=5)
maps_flow = step3_read_maps_flow(flow_dataset_params)
step3_save_flow_dataset(maps_flow)

# hitsounds dataset, only for taiko maps
# maps_hs_af, maps_hs = step3_read_maps_hs(flow_dataset_params)
# step3_save_hs_dataset(maps_hs_af, maps_hs)

# pattern dataset, only for mania (remove the flow part for mania)
# data = step3_read_maps_pattern([])
# step3_save_pattern_dataset(data)

# %% [markdown]
# That's it! The models are trained. Start making a new map with the other notebook.
